# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Bangladesh
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1", "CR10": "q2", "CR14": "q3", "CR5": "q4", "CR9": "q5",
    "CR13": "q6", "CR39": "q7", "CR40": "q8", "CR1": "q9", "CR2": "q10",
    "CR19": "q11", "CR20": "q12", "CR21": "q13", "CR22": "q14", "CR23": "q15",
    "CR24": "q16", "CR25": "q17", "CR30": "q18", "CR31": "q19", "CR32": "q20",
    "CR33": "q21", "CR34": "q22", "CR35": "q23", "CR36": "q24", "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
df.to_csv('Banglasesh_13.csv', index=False)

# %%
# Bhutan_13
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Bhutan_19
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "BTR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Maldives_19
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Mayanmar-16
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR2": "q9",
    "CR1": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Mayanmar-16
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR2": "q9",
    "CR1": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Sri-lanka-15
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Thiland-15
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
# Thiland-15
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
import numpy as np

df.rename(columns=rename_dict, inplace=True)

# create missing column q16
df["q16"] = np.nan

# if q26 somehow doesn't exist, force create
if "q26" not in df.columns:
    df["q26"] = np.nan

# %%
# Thiland-15
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CSV Data/South east asia/BANGLADESH_13.csv')
# Rename columns
rename_dict = {
    "CR7": "q1",
    "CR10": "q2",
    "CR14": "q3",
    "CR5": "q4",
    "CR9": "q5",
    "CR13": "q6",
    "CR39": "q7",
    "CR40": "q8",
    "CR1": "q9",
    "CR2": "q10",
    "CR19": "q11",
    "CR20": "q12",
    "CR21": "q13",
    "CR22": "q14",
    "CR23": "q15",
    "CR24": "q16",
    "CR25": "q17",
    "CR30": "q18",
    "CR31": "q19",
    "CR32": "q20",
    "CR33": "q21",
    "CR34": "q22",
    "CR35": "q23",
    "CR36": "q24",
    "CR37": "q25",
    "CR38": "q26"
}

df = df[list(rename_dict.keys())].rename(columns=rename_dict).copy()

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('BANGLADESH_04.csv')
df2 = pd.read_csv('BANGLADESH_National_07.csv')
df3 = pd.read_csv('BANGLADESH_13.csv')

# %%
df1['year'] = 2004
df2['year'] = 2007

# %%
df1 = df1.rename(columns={
    'INR1': 'CR1',
    'INR2': 'CR2',
    'INR6': 'CR3',
    'INR10': 'BDR5',
    'BDR10': 'BDR6',
    'BDR12': 'BDR7',
    'BDR14': 'BDR8',
    'BDR16': 'BDR9',
    'CR10': 'CR7',
    'INR23': 'CR10_new',
    'INR26': 'CR11',
    'INR9': 'BDR16',
    'INR22': 'BDR18',
    'INR28': 'CR13',
    'INR29': 'CR14',
    'INR30': 'CR15',
    'INR32': 'CR17',

    'INR33': 'CR18',
    'INR34': 'CR19',
    'INR35': 'CR20',
    'INR36': 'CR21',
    'INR37': 'CR22',
    'INR38': 'CR23',
    'INR40': 'CR24',
    'INR42': 'CR25',
    'INR44': 'CR26',
    'INR45': 'CR27',
    'INR46': 'CR28',
    'INR48': 'CR29',
    'CR32': 'CR30',
    'CR33': 'CR31',
    'INR52': 'CR33',
    'INR53': 'CR34',
    'INR55': 'CR36',
    'INR56': 'CR37',
    'INR57': 'CR38',
    'CR41': 'CR39',
    'INR59': 'CR40',
    'INR60': 'CR41',
    'BDR54': 'CR42',
    'INR42': 'CR25',
    'INR44': 'CR26',
    'INR45': 'CR27',
    'INR46': 'CR28',
    'INR48': 'CR29',
    'CR32': 'CR30',
    'CR33': 'CR31',
    'INR52': 'CR33',
    'INR53': 'CR34',

    'BDR55': 'CR43',
    'INR66': 'CR44',
    'INR67': 'BDR62',
    'BDR58': 'BDR63',
    'INR71': 'CR46',
    'INR72': 'BDR65',
    'INR74': 'CR47',
    'INR75': 'BDR67',
    'INR77': 'CR48',
    'INR78': 'CR49',
    'INR80': 'BDR70'
})

# %%
df1 = df1.rename(columns={'CR10_new': 'CR10'})
df1.columns
# Out:
# Index(['FinalWgt', 'CR1', 'CR2', 'INR3', 'BDR4', 'CR3', 'INR7', 'CR4', 'BDR16',
#        'BDR5', 'BDR6', 'BDR11', 'BDR7', 'BDR13', 'BDR8', 'BDR15', 'BDR9',
#        'CR7', 'BDR18', 'CR10', 'BDR20', 'CR11', 'INR27', 'CR13', 'CR14',
#        'CR15', 'INR31', 'CR17', 'CR18', 'CR19', 'CR20', 'CR21', 'CR22', 'CR23',
#        'CR24', 'CR25', 'CR26', 'CR27', 'CR28', 'CR29', 'CR30', 'CR31', 'CR35',
#        'CR33', 'CR34', 'INR54', 'CR36', 'CR37', 'CR38', 'CR39', 'CR40', 'CR41',
#        'INR61', 'INR62', 'CR42', 'CR43', 'CR44', 'BDR62', 'BDR63', 'CR46',
#        'BDR65', 'CR47', 'BDR67', 'CR48', 'CR49', 'INR79', 'BDR70', 'CR55',
#        'CR56', 'BDR83', 'Stratum', 'PSU', 'Year'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['FinalWgt', 'CR1', 'CR2', 'CR3', 'CR4', 'BDR5', 'BDR6', 'BDR7', 'BDR8',
#        'BDR9', 'CR7', 'CR10', 'CR11', 'BDR13', 'BDR14', 'BDR15', 'BDR16',
#        'BDR17', 'BDR18', 'BDR19', 'BDR20', 'BDR21', 'BDR22', 'BDR23', 'CR12',
#        'BDR25', 'BDR26', 'CR13', 'CR14', 'CR15', 'CR16', 'CR17', 'CR18',
#        'CR19', 'CR20', 'CR21', 'CR22', 'CR23', 'CR24', 'BDR39', 'BDR40',
#        'CR25', 'CR26', 'CR27', 'CR28', 'CR29', 'CR30', 'CR31', 'CR32', 'CR33',
#        'BDR50', 'CR34', 'CR35', 'CR36', 'CR37', 'CR38', 'CR39', 'CR40', 'CR41',
#        'CR42', 'CR43', 'CR44', 'BDR62', 'BDR63', 'CR46', 'BDR65', 'CR47',
#        'BDR67', 'CR48', 'CR49', 'BDR70', 'CR52', 'CR53', 'BDR73', 'Stratum',
#        'PSU'],
#       dtype='object')

# %%
common_cols = df1.columns.intersection(df2.columns)

df1_common = df1[common_cols]
df2_common = df2[common_cols]
merged = pd.concat([df1_common, df2_common], ignore_index=True)

# %%
df1.columns.intersection(df2.columns)
# Out:
# Index(['FinalWgt', 'CR1', 'CR2', 'CR3', 'CR4', 'BDR16', 'BDR5', 'BDR6', 'BDR7',
#        'BDR13', 'BDR8', 'BDR15', 'BDR9', 'CR7', 'BDR18', 'CR10', 'BDR20',
#        'CR11', 'CR13', 'CR14', 'CR15', 'CR17', 'CR18', 'CR19', 'CR20', 'CR21',
#        'CR22', 'CR23', 'CR24', 'CR25', 'CR26', 'CR27', 'CR28', 'CR29', 'CR30',
#        'CR31', 'CR35', 'CR33', 'CR34', 'CR36', 'CR37', 'CR38', 'CR39', 'CR40',
#        'CR41', 'CR42', 'CR43', 'CR44', 'BDR62', 'BDR63', 'CR46', 'BDR65',
#        'CR47', 'BDR67', 'CR48', 'CR49', 'BDR70', 'Stratum', 'PSU'],
#       dtype='object')

# %%
merged.shape
# Out:
# (4634, 59)

# %%
merged.columns
# Out:
# Index(['FinalWgt', 'CR1', 'CR2', 'CR3', 'CR4', 'BDR16', 'BDR5', 'BDR6', 'BDR7',
#        'BDR13', 'BDR8', 'BDR15', 'BDR9', 'CR7', 'BDR18', 'CR10', 'BDR20',
#        'CR11', 'CR13', 'CR14', 'CR15', 'CR17', 'CR18', 'CR19', 'CR20', 'CR21',
#        'CR22', 'CR23', 'CR24', 'CR25', 'CR26', 'CR27', 'CR28', 'CR29', 'CR30',
#        'CR31', 'CR35', 'CR33', 'CR34', 'CR36', 'CR37', 'CR38', 'CR39', 'CR40',
#        'CR41', 'CR42', 'CR43', 'CR44', 'BDR62', 'BDR63', 'CR46', 'BDR65',
#        'CR47', 'BDR67', 'CR48', 'CR49', 'BDR70', 'Stratum', 'PSU'],
#       dtype='object')

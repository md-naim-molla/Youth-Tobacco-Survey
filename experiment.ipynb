# %%
import pandas as pd

# %%
ban = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CODE/Bangladesh_13.csv')
ban.shape
# Out:
# (3245, 30)

# %%
df = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CODE/South_East_Asia.csv')

# %%
sum(df['Country'] == 'Bangladesh')
# Out:
# 3245

# %%
df1 = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CODE/Timor_13.csv')
df1.shape
# Out:
# (2052, 30)

# %%
df1 = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CODE/Timor_19.csv')
df1.shape
# Out:
# (3474, 30)

# %%
sum(df['Country'] == 'Timor-Leste')
# Out:
# 5526

# %%
print(3474+2052)
# Out:
# 5526

# %%
df1 = pd.read_csv(r'/home/imran/Desktop/Nayeem/Youth-Tobacco-Survey/CODE/Sri-lanka_15.csv')
df1.shape
# Out:
# (1505, 30)

# %%
sum(df['Country'] == '')
# Out:
# 1505
